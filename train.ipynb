# %% [markdown]
# # Training

# %% [markdown]
# ## Resnet-20

# %% [markdown]
# ### BasicReLU

# %%
! python cifar_main.py --arch resnet --depth 20 --tena BasicReLU --exp_dir exp/resnet20/BasicReLU
# Out:
# ==> Preparing dataset cifar10
# Files already downloaded and verified
# ==> creating tena unit 'BasicReLU'
# ==> creating model 'resnet'
#     Total params: 0.27M
# BasicReLU updated: 0 (no effect)
#
# Epoch: [1 | 200] LR: 0.100000
# Train Loss/Acc: 1.61/39.51
# Test Loss/Acc: 1.43/48.15
# BasicReLU updated: 1 (no effect)
#
# Epoch: [2 | 200] LR: 0.100000
# Train Loss/Acc: 1.11/60.15
# Test Loss/Acc: 1.03/63.20
# BasicReLU updated: 2 (no effect)
#
# Epoch: [3 | 200] LR: 0.100000
# Train Loss/Acc: 0.90/67.89
# Test Loss/Acc: 0.99/66.92
# BasicReLU updated: 3 (no effect)
#
# Epoch: [4 | 200] LR: 0.100000
# Train Loss/Acc: 0.78/72.89
# Test Loss/Acc: 0.82/72.52
# BasicReLU updated: 4 (no effect)
#
# Epoch: [5 | 200] LR: 0.100000
# Train Loss/Acc: 0.71/75.29
# Test Loss/Acc: 0.97/70.12
# BasicReLU updated: 5 (no effect)
#
# Epoch: [6 | 200] LR: 0.100000
# Train Loss/Acc: 0.66/77.27
# Test Loss/Acc: 0.99/66.66
# BasicReLU updated: 6 (no effect)
#
# Epoch: [7 | 200] LR: 0.100000
# ...

# %% [markdown]
# ### TenaReLU

# %%
! python cifar_main.py --arch resnet --depth 20 --tena TenaReLU --exp_dir exp/resnet20/TenaReLU

# %% [markdown]
# ## Resnet-50

# %% [markdown]
# ### BasicReLU

# %%
! python cifar_main.py --arch resnet --depth 50 --tena BasicReLU --exp_dir exp/resnet50/BasicReLU

# %% [markdown]
# ### TenaReLU

# %%
! python cifar_main.py --arch resnet --depth 50 --tena TenaReLU --exp_dir exp/resnet50/TenaReLU

# %% [markdown]
# ## Resnet-110

# %% [markdown]
# ### BasicReLU

# %%
! python cifar_main.py --arch resnet --depth 110 --tena BasicReLU --exp_dir exp/resnet110/BasicReLU

# %% [markdown]
# ### TenaReLU

# %%
! python cifar_main.py --arch resnet --depth 110 --tena TenaReLU --exp_dir exp/resnet110/TenaReLU
